# %%
# Beat tracking example
from __future__ import print_function
import librosa
import librosa.display

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import IPython.display as ipd

# %%
import numpy as np
import pandas as pd

# %%
SR = 22050

# %% [markdown]
# ### LOAD DATASET

# %%
X_mel = np.load('data/features/X_mel_002.npy')

# %%
X_mel.shape
# Out:
# (1532, 60, 35)

# %% [markdown]
# ## chew-bite

# %%
S_dB = X_mel[0,:,:]

# %%
plt.figure(figsize=(10, 4))
#S_dB = librosa.power_to_db(S, ref=np.max)
librosa.display.specshow(S_dB, x_axis='time',
                          y_axis='mel', sr=SR,
                          fmax=SR/2)
plt.colorbar(format='%+2.0f dB')
plt.title('Mel-frequency spectrogram')
plt.tight_layout()
plt.show()

# %%
S_dB = X_mel[1,:,:]

# %%
plt.figure(figsize=(10, 4))
#S_dB = librosa.power_to_db(S, ref=np.max)
librosa.display.specshow(S_dB, x_axis='time',
                          y_axis='mel', sr=SR,
                          fmax=SR/2)
plt.colorbar(format='%+2.0f dB')
plt.title('Mel-frequency spectrogram')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## chew

# %%
S_dB = X_mel[2,:,:]

# %%
plt.figure(figsize=(10, 4))
#S_dB = librosa.power_to_db(S, ref=np.max)
librosa.display.specshow(S_dB, x_axis='time',
                          y_axis='mel', sr=SR,
                          fmax=SR/2)
plt.colorbar(format='%+2.0f dB')
plt.title('Mel-frequency spectrogram')
plt.tight_layout()
plt.show()

# %%
S_dB = X_mel[8,:,:]

# %%
plt.figure(figsize=(10, 4))
#S_dB = librosa.power_to_db(S, ref=np.max)
librosa.display.specshow(S_dB, x_axis='time',
                          y_axis='mel', sr=SR,
                          fmax=SR/2)
plt.colorbar(format='%+2.0f dB')
plt.title('Mel-frequency spectrogram')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## bite

# %%
S_dB = X_mel[24,:,:]

# %%
plt.figure(figsize=(10, 4))
#S_dB = librosa.power_to_db(S, ref=np.max)
librosa.display.specshow(S_dB, x_axis='time',
                          y_axis='mel', sr=SR,
                          fmax=SR/2)
plt.colorbar(format='%+2.0f dB')
plt.title('Mel-frequency spectrogram')
plt.tight_layout()
plt.show()

# %%
S_dB = X_mel[48,:,:]

# %%
plt.figure(figsize=(10, 4))
#S_dB = librosa.power_to_db(S, ref=np.max)
librosa.display.specshow(S_dB, x_axis='time',
                          y_axis='mel', sr=SR,
                          fmax=SR/2)
plt.colorbar(format='%+2.0f dB')
plt.title('Mel-frequency spectrogram')
plt.tight_layout()
plt.show()

# %%
plt.imshow(S_dB)
